# %%
import numpy as np

from main import predicted_periods

# %%
trained_model = np.load('../data/models/hpc/trained_model/A-30000_-29800_B1500_50000.npy')

# %%
print(trained_model.shape)
# Out:
# (1, 1)

# %%
print(trained_model)
# Out:
# [['./data/models/hpc/hpc_N32_A-30000_-29800_B1500_50000_batch1024_lr0.0005_Adabound.pt']]

# %%
predicted_periods1 = np.load('../data/results/hpc/predicted_periods_20250605-154150.npy', allow_pickle=True)

# %%
print(predicted_periods1)
# Out:
# [list([np.int64(-50000), np.int64(-49950), np.int64(-49900), np.int64(-49850), np.int64(-49800)])
#  list([np.int64(-48800), np.int64(-48750), np.int64(-48700), np.int64(-48650), np.int64(-48600)])
#  list([np.int64(-48000), np.int64(-47950), np.int64(-47900), np.int64(-47850), np.int64(-47800), np.int64(-47800), np.int64(-47750), np.int64(-47700), np.int64(-47650), np.int64(-47600), np.int64(-47600), np.int64(-47550), np.int64(-47500), np.int64(-47450), np.int64(-47400)])
#  list([np.int64(-46400), np.int64(-46350), np.int64(-46300), np.int64(-46250), np.int64(-46200)])
#  list([np.int64(-45800), np.int64(-45750), np.int64(-45700), np.int64(-45650), np.int64(-45600)])
#  list([np.int64(-45000), np.int64(-44950), np.int64(-44900), np.int64(-44850), np.int64(-44800)])
# ...

# %%
print(len(predicted_periods1))
for period in predicted_periods1:
    print(f"{period[0]} ~ {period[-1]}")
# Out:
# 47
# -50000 ~ -49800
# -48800 ~ -48600
# -48000 ~ -47400
# -46400 ~ -46200
# -45800 ~ -45600
# -45000 ~ -44800
# -44000 ~ -43400
# -41600 ~ -41200
# -37400 ~ -37000
# -35000 ~ -34800
# -33000 ~ -32800
# -31000 ~ -30400
# -26600 ~ -26400
# -14000 ~ -13800
# -11400 ~ -11200
# -10000 ~ -9800
# -8600 ~ -8400
# -7200 ~ -7000
# -5800 ~ -5600
# -3000 ~ -2800
# 2400 ~ 2800
# 5000 ~ 5400
# 7200 ~ 7600
# 9800 ~ 10000
# 14400 ~ 15200
# 21200 ~ 21400
# 21600 ~ 21800
# 22600 ~ 22800
# 24200 ~ 24400
# 25200 ~ 25400
# 25600 ~ 25800
# 27000 ~ 27400
# 28400 ~ 28600
# 29600 ~ 30000
# 31200 ~ 31800
# 32800 ~ 33000
# 33400 ~ 33600
# 34000 ~ 34400
# 35600 ~ 36400
# 38000 ~ 38800
# 40000 ~ 40400
# 41200 ~ 41800
# 42800 ~ 43200
# 45600 ~ 46400
# 47200 ~ 47400
# 48000 ~ 48200
# 48600 ~ 49200

# %%
predicted_periods2 = np.load('../data/results/hpc/predicted_periods_20250605-154909.npy', allow_pickle=True)

# %%
print(len(predicted_periods1))
for period in predicted_periods1:
    print(f"{period[0]} ~ {period[-1]}")
# Out:
# 47
# -50000 ~ -49800
# -48800 ~ -48600
# -48000 ~ -47400
# -46400 ~ -46200
# -45800 ~ -45600
# -45000 ~ -44800
# -44000 ~ -43400
# -41600 ~ -41200
# -37400 ~ -37000
# -35000 ~ -34800
# -33000 ~ -32800
# -31000 ~ -30400
# -26600 ~ -26400
# -14000 ~ -13800
# -11400 ~ -11200
# -10000 ~ -9800
# -8600 ~ -8400
# -7200 ~ -7000
# -5800 ~ -5600
# -3000 ~ -2800
# 2400 ~ 2800
# 5000 ~ 5400
# 7200 ~ 7600
# 9800 ~ 10000
# 14400 ~ 15200
# 21200 ~ 21400
# 21600 ~ 21800
# 22600 ~ 22800
# 24200 ~ 24400
# 25200 ~ 25400
# 25600 ~ 25800
# 27000 ~ 27400
# 28400 ~ 28600
# 29600 ~ 30000
# 31200 ~ 31800
# 32800 ~ 33000
# 33400 ~ 33600
# 34000 ~ 34400
# 35600 ~ 36400
# 38000 ~ 38800
# 40000 ~ 40400
# 41200 ~ 41800
# 42800 ~ 43200
# 45600 ~ 46400
# 47200 ~ 47400
# 48000 ~ 48200
# 48600 ~ 49200

# %%
predicted_periods_with_num = np.load('../data/results/spin_num/regression_results_with_spin_nums_20250605-154009.npy', allow_pickle=True)

# %%
print(len(predicted_periods_with_num))
# Out:
# 0

# %%
spin_nums1 = np.load('../data/results/spin_num/regression_results_with_spin_nums_20250530-100843.npy', allow_pickle=True)

# %%
print(len(spin_nums1))
for period in spin_nums1:
    print(period[0])
    print(period[1])
    print(len(period[2]))
    for p in period[2]:
        print(f"period {p[0]} ~ {p[-1]}")
# Out:
# 3
# [array([0.83441293, 0.15935028, 0.03311372], dtype=float32), 3, 2]
# [array([0.8400868 , 0.16012739, 0.0313812 ], dtype=float32), 3, 2]
# 2
# period [1] ~ [3]
# period [1, 3] ~ [1, 3]
# [array([0.8647232 , 0.12396412, 0.0264184 ], dtype=float32), 3, 2]
# [array([0.8711794 , 0.12049462, 0.02431042], dtype=float32), 3, 2]
# 2
# period [1] ~ [3]
# period [1, 3] ~ [1, 3]
# [array([5.3353113e-05, 9.9489599e-01, 1.1879074e-02, 4.6260869e-03,
#        1.0064705e-03, 2.0441256e-04], dtype=float32), 6, 7]
# [array([4.4117907e-05, 9.9544501e-01, 1.2621710e-02, 4.3466124e-03,
#        9.5208152e-04, 2.0113301e-04], dtype=float32), 6, 7]
# 5
# period [1] ~ [27]
# period [np.int64(2), np.int64(7), np.int64(14), np.int64(22)] ~ [np.int64(2), np.int64(7), np.int64(22), np.int64(26)]
# period [np.int64(6), np.int64(11), np.int64(17), np.int64(23), np.int64(27)] ~ [np.int64(1), np.int64(9), np.int64(17), np.int64(23), np.int64(27)]
# ...

# %%
spin_nums2 = np.load('../data/results/spin_num/regression_results_with_spin_nums_20250605-160226.npy', allow_pickle=True)

# %%
print(len(spin_nums2))
# Out:
# 45

# %%
spin_nums3 = np.load('../data/results/spin_num/regression_results_with_spin_nums_20250605-171329.npy', allow_pickle=True)

# %%
print(len(spin_nums3))
# Out:
# 47

# %%
for i in range(len(spin_nums3)):
    print(spin_nums3[i][0])
    print(spin_nums3[i][1])
# Out:
# [array([6.8761292e-04, 2.0264564e-01, 9.7164583e-01], dtype=float32), 3, 2]
# [array([0.0034065 , 0.23986888, 0.9304095 ], dtype=float32), 3, 2]
# [array([0.01148034, 0.38094005, 0.9357967 ], dtype=float32), 3, 2]
# [array([0.02423909, 0.33849692, 0.88239014], dtype=float32), 3, 2]
# [array([3.8739977e-06, 2.2108665e-04, 2.5596565e-01, 9.9544621e-01],
#       dtype=float32), 4, 4]
# [array([6.2331666e-05, 1.4812625e-03, 2.4010637e-01, 9.7919762e-01],
#       dtype=float32), 4, 4]
# [array([0.00703067, 0.06457361, 0.86770236], dtype=float32), 3, 2]
# [array([0.01835418, 0.12602025, 0.79863286], dtype=float32), 3, 2]
# [array([0.00518384, 0.30239034, 0.88531774], dtype=float32), 3, 2]
# [array([0.01858653, 0.3025997 , 0.76730967], dtype=float32), 3, 2]
# [array([0.00990238, 0.4589404 , 0.82836515], dtype=float32), 3, 2]
# [array([0.03045365, 0.42308393, 0.74187714], dtype=float32), 3, 2]
# [array([4.1706762e-06, 6.7319826e-04, 5.0570476e-01, 9.7325212e-01],
# ...

# %%
AB_values = np.load('../data/results/regression/regression_AB_results_20250605-180129.npy', allow_pickle=True)

# %%
print(len(AB_values))
# Out:
# 47

# %%
total_AB_values = []
for i in range(len(AB_values)):
    num = int(len(AB_values[i])/2)
    for j in range(num):
        total_AB_values.append([AB_values[i][2*j], AB_values[i][2*j+1]])

# %%
print(len(total_AB_values))
# Out:
# 128

# %%
print(total_AB_values)
# Out:
# [[np.float64(-49926.322619731116), np.float64(52439.517390728)], [np.float64(-49593.758797457784), np.float64(50818.69823336601)], [np.float64(-48661.46681748313), np.float64(46367.804872989655)], [np.float64(-48718.74198604513), np.float64(51209.357273578644)], [np.float64(-48703.37581649737), np.float64(-29976.65023803711)], [np.float64(-49518.65576368466), np.float64(45969.573295116425)], [np.float64(-47897.800122696586), np.float64(16890.12327194214)], [np.float64(-53624.32477344611), np.float64(53357.096552848816)], [np.float64(-49100.27378039215), np.float64(25951.91249847412)], [np.float64(-49071.51579321389), np.float64(38487.02211380005)], [np.float64(-45895.347219699084), np.float64(45975.05586147308)], [np.float64(-45183.69761207814), np.float64(52891.0365819931)], [np.float64(-44850.95396519124), np.float64(48698.03817868233)], [np.float64(-44661.35728266272), np.float64(47673.94411563873)], [np.float64(-45294.21963940707), np.float64(25921.08235359192)], [np.float64(-475
# ...
