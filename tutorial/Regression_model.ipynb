# %% [markdown]
# ____
# ### This tutorial provides each step to build and train the regression model.
#
# The model specifies hyperfine parameters with using predicted periods from HPC models. (see details about HPC models in Part 3 and 4 of tutorial)
#
# ____
# Note1: To run this notebook, first click "Open in playgound" tab above. You may need "Chrome" browser and "Gmail account". Then in each cell, press 'Shift + Enter'
#
# Note2: It doesn't need any packages or programs and also doesn't store any files in your device.

# %%
from imports.models import *
from imports.utils import *
import adabound as Adabound

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
import glob
import sys
import time
np.set_printoptions(suppress=True)

# %%
from multiprocessing import Pool
POOL_PROCESS = 23
FILE_GEN_INDEX = 2
pool = Pool(processes=POOL_PROCESS)

import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.utils import shuffle
import itertools

# %%
# time index dictionary file corresponding target periods (see Supplementary Note 1)
total_indices = np.load('/content/Deep_Learning_CPMG_Analysis/tutorial_data/total_indices_v4_full.npy', allow_pickle=True).item()

# (A, B) pairs which corresponds each target period. (Equation is described in the paper)
AB_lists_dic = np.load('/content/Deep_Learning_CPMG_Analysis/tutorial_data/AB_target_dic_v4_s0.npy', allow_pickle=True).item()
for i in range(1, 16):
    temp = np.load('/content/Deep_Learning_CPMG_Analysis/tutorial_data/AB_target_dic_v4_s{}.npy'.format(i), allow_pickle=True).item()
    AB_lists_dic.update(temp)

# %%
print("Generating a CPMG signal with target spins.")
MAGNETIC_FIELD = 403.553                        # Unit: Gauss
GYRO_MAGNETIC_RATIO = 1.0705*1000               # Unit: Herts
WL_VALUE = MAGNETIC_FIELD*GYRO_MAGNETIC_RATIO*2*np.pi

CUDA_DEVICE = 0
torch.cuda.set_device(device=CUDA_DEVICE)
N_PULSE = 256
PRE_PROCESS = False
PRE_SCALE = 1

test_spins = np.array([
                       [18000, 2800], # similar spin to C1 in the paper --> a target spin in this tutorial
                       [-23000, 8700],   # test spin                      --> a target spin in this tutorial
                       [5500, 7150],    # residual spin
                       [15100, 27000],   # residual spin
                       [32200, 13260],   # residual spin
                       [47600, 23200],   # residual spin
                       [32800, 46420],   # residual spin
                       [-27000, 53000],   # residual spin
                       [-57000, 11140],   # residual spin
                       [-30100, 5820],   # residual spin
                       ])*2*np.pi

time_resolution = 0.004
time_data = np.arange(0, 60, time_resolution)

IMAGE_WIDTH = 10
TIME_RANGE  = 10000

test_data_M = M_list_return(time_data*1e-6, WL_VALUE, test_spins, N_PULSE)
test_data = (1+test_data_M) / 2
# Out:
# Generating a CPMG signal with target spins.

# %%
fig = go.Figure()
fig.update_layout(
    title={
          'text': "Test CPMG Signal (N=256)",
          'y':0.9,
          'x':0.5,
          'xanchor': 'center',
          'yanchor': 'top'
          },
    xaxis_title="us",
    yaxis_title="Px",
    font=dict(
        family="Arial",
        size=18
    )
)
fig.add_trace(
    go.Scatter(x=time_data, y=test_data, name='CPMG signal')
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0f5c8356-995e-466b-b00b-45c98a04d9b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0f5c8356-995e-466b-b00b-45c98a04d9b8")) {
#                     Plotly.newPlot(
#                         '0f5c8356-995e-466b-b00b-45c98a04d9b8',
#                         [{"name": "CPMG signal", "type": "scatter", "x": [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024, 0.028, 0.032, 0.036000000000000004, 0.04, 0.044, 0.048, 0.052000000000000005, 0.056, 0.06, 0.064, 0.068, 0.07200000000000001, 0.076, 0.08, 0.084, 0.088, 0.092, 0.096, 0.1, 0.10400000000000001, 0.108, 0.112, 0.116, 0.12, 0.124, 0.128, 0.132, 0.136, 0.14, 0.14400000000000002, 0.148, 0.152, 0.156, 0.16, 0.164, 0.168, 0.17200000000000001, 0.176, 0.18, 0.184, 0.188, 0.192, 0.196, 0.2, 0.20400000000000001, 0.20800000000000002, 0.212, 0.216, 0.22, 0.224, 0.228, 0.232, 0.23600000000000002, 0.24, 0.244, 0.248, 0.252, 0.256, 0.26, 0.264, 0.268, 0.272, 0.276, 0.28, 0.28400000000000003, 0.28800000000000003, 0.292, 0.296, 0.3, 0.304, 0.308, 0.312, 0.316, 0.32, 0.324, 0.328, 0.332, 0.336, 0.34, 0.34400000000000003, 0.34800000000000003, 0.352, 0.356, 0.36, 0.364, 0.368, 0.372, 0.376, 0.38, 0.384, 0.388, 0.392, 0.396, 0.4, 0.404, 0.40800000000000003, 0.41200000000000003, 0.41600000000000004, 0.42, 0.424, 0.428, 0.432, 0.436, 0.44, 0.444, 0.448, 0.452, 0.456, 0.46, 0.464, 0.468, 0.47200000000000003, 0.47600000000000003, 0.48, 0.484, 0.488, 0.492, 0.496, 0.5, 0.504, 0.508, 0.512, 0.516, 0.52, 0.524, 0.528, 0.532, 0.536, 0.54, 0.544, 0.548, 0.552, 0.556, 0.56, 0.5640000000000001, 0.5680000000000001, 0.5720000000000001, 0.5760000000000001, 0.58, 0.584, 0.588, 0.592, 0.596, 0.6, 0.604, 0.608, 0.612, 0.616, 0.62, 0.624, 0.628, 0.632, 0.636, 0.64, 0.644, 0.648, 0.652, 0.656, 0.66, 0.664, 0.668, 0.672, 0.676, 0.68, 0.684, 0.6880000000000001, 0.6920000000000001, 0.6960000000000001, 0.7000000000000001, 0.704, 0.708, 0.712, 0.716, 0.72, 0.724, 0.728, 0.732, 0.736, 0.74, 0.744, 0.748, 0.752, 0.756, 0.76, 0.764, 0.768, 0.772, 0.776, 0.78, 0.784, 0.788, 0.792, 0.796, 0.8, 0.804, 0.808, 0.812, 0.8160000000000001, 0.8200000000000001, 0.8240000000000001, 0.8280000000000001, 0.8320000000000001, 0.836, 0.84, 0.844, 0.848, 0.852, 0.856, 0.86, 0.864, 0.868, 0.872, 0.876, 0.88, 0.884, 0.888, 0.892, 0.896, 0.9, 0.904, 0.908, 0.912, 0.916, 0.92, 0.924, 0.928, 0.932, 0.936, 0.9400000000000001, 0.9440000000000001, 0.9480000000000001, 0.9520000000000001, 0.9560000000000001, 0.96, 0.964, 0.968, 0.972, 0.976, 0.98, 0.984, 0.988, 0.992, 0.996, 1.0, 1.004, 1.008, 1.012, 1.016, 1.02, 1.024, 1.028, 1.032, 1.036, 1.04, 1.044, 1.048, 1.052, 1.056, 1.06, 1.064, 1.068, 1.072, 1.076, 1.08, 1.084, 1.088, 1.092, 1.096, 1.1, 1.104, 1.108, 1.112, 1.116, 1.12, 1.124, 1.1280000000000001, 1.1320000000000001, 1.1360000000000001, 1.1400000000000001, 1.1440000000000001, 1.1480000000000001, 1.1520000000000001, 1.156, 1.16, 1.164, 1.168, 1.172, 1.176, 1.18, 1.184, 1.188, 1.192, 1.196, 1.2, 1.204, 1.208, 1.212, 1.216, 1.22, 1.224, 1.228, 1.232, 1.236, 1.24, 1.244, 1.248, 1.252, 1.256, 1.26, 1.264, 1.268, 1.272, 1.276, 1.28, 1.284, 1.288, 1.292, 1.296, 1.3, 1.304, 1.308, 1.312, 1.316, 1.32, 1.324, 1.328, 1.332, 1.336, 1.34, 1.344, 1.348, 1.352, 1.356, 1.36, 1.364, 1.368, 1.372, 1.3760000000000001, 1.3800000000000001, 1.3840000000000001, 1.3880000000000001, 1.3920000000000001, 1.3960000000000001, 1.4000000000000001, 1.4040000000000001, 1.408, 1.412, 1.416, 1.42, 1.424, 1.428, 1.432, 1.436, 1.44, 1.444, 1.448, 1.452, 1.456, 1.46, 1.464, 1.468, 1.472, 1.476, 1.48, 1.484, 1.488, 1.492, 1.496, 1.5, 1.504, 1.508, 1.512, 1.516, 1.52, 1.524, 1.528, 1.532, 1.536, 1.54, 1.544, 1.548, 1.552, 1.556, 1.56, 1.564, 1.568, 1.572, 1.576, 1.58, 1.584, 1.588, 1.592, 1.596, 1.6, 1.604, 1.608, 1.612, 1.616, 1.62, 1.624, 1.6280000000000001, 1.6320000000000001, 1.6360000000000001, 1.6400000000000001, 1.6440000000000001, 1.6480000000000001, 1.6520000000000001, 1.6560000000000001, 1.6600000000000001, 1.6640000000000001, 1.668, 1.672, 1.676, 1.68, 1.684, 1.688, 1.692, 1.696, 1.7, 1.704, 1.708, 1.712, 1.716, 1.72, 1.724, 1.728, 1.732, 1.736, 1.74, 1.744, 1.748, 1.752, 1.756, 1.76, 1.764, 1.768, 1.772, 1.776, 1.78, 1.784, 1.788, 1.792, 1.796, 1.8, 1.804, 1.808, 1.812, 1.816, 1.82, 1.824, 1.828, 1.832, 1 ...

# %%
# Assume that HPC models successfully predict high confidence scores for target preriods of two target spins in the above cell.
# Generally, when a single spin exists, HPC model predicts high confidence scores for the range of 2~4 target periods (if evalutation step size=50Hz).

A_lists = np.array(
      [
       [[17900-50, 17900, 17900+50], [-1]],   # Assume this is the prediction result(=predicted target periods of high confidence scores) from HPC model.
                                              # , [-1] means the number of spin is one within the predicted target periods.
       [[-23050, -23050+50], [-1]],
      ]
    , dtype=object)

# %%
IMAGE_WIDTH = 8
TIME_RANGE  = 5000
num_of_summation = 4

B_init  = 1500
B_final = 25000
noise_scale = 0.07

cpu_num_for_multi = 20    # the number of cpu-thread used for generating datasets
batch_for_multi = 64      # the number of batch size per cpu-thread
class_batch = cpu_num_for_multi*batch_for_multi # the number of batch per class

A_target_margin = 25           # the marginal range of the target spins. (Hz)
A_side_margin = 250            # the marginal range of the side spins. (Hz)
A_final_margin = 20            # the marginal range of the final target spins. (Hz)
distance_btw_target_side = 500 # distance_btw_target_side - (A_target_margin+A_side_margin)
                               # = the final distance between target and side
                               # this distance highly affects the loss during the trainnig
                               # because it gets more difficult as the distance gets narrower

A_far_side_margin = 5000       # the marginal range of the far_side spins. (Hz)
side_candi_num = 5             # the number of "how many times" to generate 'AB_side_candidate'

A_num = 1    # this determines how many sections will be divided within the whole target range of A
B_num = 1    # this determines how many sections will be divided within the whole target range of B
class_num = A_num*B_num + 1   # CAUTION: class_num = 'how many classes in a target AB candidates'
image_width = IMAGE_WIDTH

A_hier_margin = 75
A_existing_margin = 150
B_existing_margin = 2500

# %% [markdown]
# ___
#
# *   Various parameters could be tested for optimal performance. See below variable lists for width, time, B_init.

# %%
width_list = [10]       # This determines a image width of trainig data. (try any values like [5,10,15,20 ....])
time_list = [5000]      # This determines a total time length to be used for trainig data. (try any values like [2000,3500,5000 ....]) and try plotting it as 2D image to see changes.
B_init_list = [2000]    # This determines a minimum B value when generating trainig data. (try any values like [1000,2000, 3500 ....]) and one may see how this affects accuracies.
B_max_list = [15000]     # This determines a maximum B value when generating trainig data. (try any values like [10000,20000,30000 ....])
samespin_zero_scale_list = [0.5]
parameter_list = [[width, total_time, bmax, B_init, samespin_zero_scale] for width, total_time, bmax, B_init, samespin_zero_scale in itertools.product(width_list, time_list, B_max_list, B_init_list, samespin_zero_scale_list)]
total_pred_list = []
for batch_for_multi in [64, 64, 64, 64, 64, 64, 64]:
    class_batch = cpu_num_for_multi*batch_for_multi # the number of batch per class
    for idx, [width, total_time, B_final, B_init, samespin_zero_scale] in enumerate(parameter_list):
        model_lists = np.array([[A_temp_list[0][0], A_temp_list[0][-1], B_init, B_final] for A_temp_list in A_lists])
        image_width = width
        TIME_RANGE = total_time

        print("================================================================================")
        print('image_width:{}, TIME_RANGE:{}, B_init:{}, B_end:{}'.format(width, total_time, B_init, B_final))
        print("================================================================================")

        for model_idx, [A_first, A_end, B_first, B_end] in enumerate(model_lists):
            hier_target_index = A_lists[model_idx][1][0] # hier_index
            print("========================================================================")
            print('A_first:{}, A_end:{}, B_first:{}, B_end:{}, Bat_mul:{}'.format(A_first, A_end, B_first, B_end, batch_for_multi))
            print("========================================================================")
            data_gen_time = time.time()
            A_resol, B_resol = 50, B_end-B_first

            A_idx_list = np.arange(A_first, A_end+A_resol, A_num*A_resol)
            if (B_end-B_first)%B_resol==0:
                B_idx_list = np.arange(B_first, B_first+B_resol, B_num*B_resol)
            else:
                B_idx_list = np.arange(B_first, B_end, B_num*B_resol)
            AB_idx_set = [[A_idx, B_idx] for A_idx, B_idx in itertools.product(A_idx_list, B_idx_list)]

            A_side_num = 8
            A_side_resol = 600
            B_side_min, B_side_max = 1000, 14000
            B_side_gap = 500  # distance between target and side (applied for both side_same and side)
            B_target_gap = 0

            spin_zero_scale = {'same':samespin_zero_scale, 'side':0.50, 'mid':0.05, 'far':0.05}  # setting 'same'=1.0 for hierarchical model

            epochs = 20
            valid_batch = 4096
            valid_mini_batch = 1024

            args = (AB_lists_dic, N_PULSE, A_num, B_num, A_resol, B_resol, A_side_num, A_side_resol, B_side_min,
                        B_side_max, B_target_gap, B_side_gap, A_target_margin, A_side_margin, A_far_side_margin,
                        class_batch, class_num, spin_zero_scale, distance_btw_target_side, side_candi_num)

            for class_idx in range(num_of_summation):
                TPk_AB_candi, _, temp_hier_target_AB_candi  = gen_TPk_AB_candidates(AB_idx_set, True, *args)
                temp_hier_target_AB_candi[:,:,0] = get_marginal_arr(temp_hier_target_AB_candi[:,:,0], A_hier_margin)
                if class_idx==0:
                    total_hier_target_AB_candi = temp_hier_target_AB_candi[:]
                    target_candidates = TPk_AB_candi[0, :, 0, :]
                    side_candidates   = TPk_AB_candi[1, :, 0, :]
                    rest_candidates   = TPk_AB_candi[1, :, 1:, :]
                else:
                    total_hier_target_AB_candi = np.concatenate((total_hier_target_AB_candi, temp_hier_target_AB_candi[:]), axis=1)
                    target_candidates = np.concatenate((target_candidates, TPk_AB_candi[0, :, 0, :]), axis=0)
                    side_candidates   = np.concatenate((side_candidates, TPk_AB_candi[1, :, 0, :]), axis=0)
                    rest_candidates   = np.concatenate((rest_candidates, TPk_AB_candi[1, :, 1:, :]), axis=0)

            hier_indices = return_total_hier_index_list(A_idx_list, cut_threshold=3)
            hier_indices = return_reduced_hier_indices(hier_indices)
            total_class_num = hier_indices[-1][0].__len__() + 1

            total_TPk_AB_candidates = np.zeros((total_class_num, num_of_summation*TPk_AB_candi.shape[1], total_class_num+TPk_AB_candi.shape[2], 2))
            indices = np.random.randint(rest_candidates.shape[0], size=(total_class_num, rest_candidates.shape[0]))
            total_TPk_AB_candidates[:, :, (total_class_num-1):-2, :] = rest_candidates[indices]
            indices = np.random.randint(side_candidates.shape[0], size=(total_class_num, side_candidates.shape[0], 2))
            total_TPk_AB_candidates[:, :, -2:, :] = side_candidates[indices]

            final_TPk_AB_candidates = total_TPk_AB_candidates[:1]
            for class_idx, hier_index in enumerate(hier_indices):
                temp_batch = total_TPk_AB_candidates.shape[1] // len(hier_index)
                for idx2, index in enumerate(hier_index):
                    temp = np.swapaxes(total_hier_target_AB_candi[index], 0, 1)
                    if idx2 < (len(hier_index)-1):
                        temp_idx = np.random.randint(total_hier_target_AB_candi.shape[1], size=(temp_batch))
                        total_TPk_AB_candidates[class_idx+1, (idx2)*temp_batch:(idx2+1)*temp_batch, :len(index)] = temp[temp_idx]
                    else:
                        residual_batch = total_TPk_AB_candidates[class_idx+1, (idx2)*temp_batch:, :len(index)].shape[0]
                        temp_idx = np.random.randint(total_hier_target_AB_candi.shape[1], size=(residual_batch))
                        total_TPk_AB_candidates[class_idx+1, (idx2)*temp_batch:, :len(index)] = temp[temp_idx]
                final_TPk_AB_candidates = np.concatenate((final_TPk_AB_candidates, total_TPk_AB_candidates[class_idx+1:class_idx+2, :, :]), axis=0)

            median_idx = len(AB_idx_set) // 2
            model_index = get_model_index(total_indices, AB_idx_set[median_idx][0], time_thres_idx=TIME_RANGE-20, image_width=image_width)

            final_TPk_hier_index = len(hier_indices) + hier_target_index + 1
            final_TPk_AB_candidates = final_TPk_AB_candidates[final_TPk_hier_index]
            num_of_target_spins = hier_indices[-1][0].__len__() + hier_target_index + 1
            Y_train_arr = final_TPk_AB_candidates[:, :num_of_target_spins]
            Y_train_arr = Y_train_arr.reshape(-1, num_of_target_spins*2)
            Y_train_arr, scale_lists = Y_train_normalization(Y_train_arr)

            X_train_arr = np.zeros((final_TPk_AB_candidates.shape[0], model_index.shape[0], 2*image_width+1))
            mini_batch = X_train_arr.shape[0] // cpu_num_for_multi
            for idx1 in range(cpu_num_for_multi):
                AB_lists_batch = final_TPk_AB_candidates[idx1*mini_batch:(idx1+1)*mini_batch]
                globals()["pool_{}".format(idx1)] = pool.apply_async(gen_M_arr_batch, [AB_lists_batch, model_index, time_data[:TIME_RANGE],
                                                                                        WL_VALUE, N_PULSE, PRE_PROCESS, PRE_SCALE,
                                                                                        noise_scale])

            for idx2 in range(cpu_num_for_multi):
                X_train_arr[idx2*mini_batch:(idx2+1)*mini_batch] = globals()["pool_{}".format(idx2)].get(timeout=None)
            print("class_idx:", class_idx, end=' ')
            print("Time consumed(s): ", round(time.time() - data_gen_time, 2))
            X_train_arr = X_train_arr.reshape(-1, model_index.flatten().shape[0])

            X_train_arr, Y_train_arr = shuffle(X_train_arr, Y_train_arr)

            model = Regression_model(X_train_arr.shape[-1], Y_train_arr.shape[-1]).cuda()
            try:
                model(torch.Tensor(X_train_arr[:16]).cuda())
            except:
                raise NameError("The input shape should be revised")
            total_parameter = sum(p.numel() for p in model.parameters())
            print('total_parameter: ', total_parameter / 1000000, 'M')

            MODEL_DIR = '/test_regression/'
            try:os.mkdir(MODEL_DIR)
            except:pass
            MODEL_PATH = MODEL_DIR + 'reg_model'

            mini_batch_list = [2048]
            learning_rate_list = [5e-6]
            op_list = [['Adabound', [30,15,7,1]]]
            criterion = nn.MSELoss().cuda()

            hyperparameter_set = [[mini_batch, learning_rate, selected_optim_name] for mini_batch, learning_rate, selected_optim_name in itertools.product(mini_batch_list, learning_rate_list, op_list)]
            print("==================== A_idx: {}, B_idx: {} ======================".format(A_first, B_first))

            total_loss, total_val_loss, total_acc, trained_model = train(MODEL_PATH, N_PULSE, X_train_arr, Y_train_arr,
                                                                         model, hyperparameter_set, criterion, epochs, valid_batch, valid_mini_batch, is_regression=True)

            model.load_state_dict(torch.load(trained_model[0][0]))
            model.eval()
            print("Model loaded as evalutation mode. Model path:", trained_model[0][0])

            test_data_test = test_data[model_index.flatten()]
            test_data_test = 1-(2*test_data_test - 1)
            test_data_test = test_data_test.reshape(1, -1)
            test_data_test = torch.Tensor(test_data_test).cuda()
            pred = model(test_data_test)
            pred = pred.detach().cpu().numpy()

            reversed_pred = reverse_normalization(pred.flatten(), scale_lists)
            total_pred_list.append(reversed_pred)
            print('Target Value: ', test_spins[model_idx]/2/np.pi)
            print('Prediction Value: ', reversed_pred)
            print('\n This predicted value is used as the initial guess value for the fine-tuning step.')
# Out:
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  24.59
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:23:31 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.43320 | Val_loss: 0.25644 % | time: 0.367(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.17132 | Val_loss: 0.23478 % | time: 0.317(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.08540 | Val_loss: 0.20355 % | time: 0.306(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.06217 | Val_loss: 0.16133 % | time: 0.28(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.05612 | Val_loss: 0.13853 % | time: 0.285(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.04573 | Val_loss: 0.11495 % | time: 0.284(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.03790 | Val_loss: 0.08802 % | time: 0.291(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.03496 | Val_loss: 0.07650 % | time: 0.289(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.03451 | Val_loss: 0.06835 % | time: 0.275(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03396 | Val_loss: 0.06538 % | time: 0.287(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03041 | Val_loss: 0.07036 % | time: 0.272(s) | lr:  1.75e-06
# Epoch:   12  | Loss = 0.02908 | Val_loss: 0.06623 % | time: 0.286(s) | lr:  6.125e-07
# Epoch:   13  | Loss = 0.02833 | Val_loss: 0.06623 % | time: 0.287(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.02933 | Val_loss: 0.06932 % | time: 0.282(s) | lr:  2.1437499999999996e-07
# Done. Training Time:  Fri Dec  3 03:23:36 2021
# Total consumed time: 4.858873605728149
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [17924.51012379336, 4733.246213197708]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.24
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:23:51 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.63271 | Val_loss: 0.28697 % | time: 0.242(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.32721 | Val_loss: 0.26982 % | time: 0.216(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.21684 | Val_loss: 0.26123 % | time: 0.202(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.18040 | Val_loss: 0.24549 % | time: 0.194(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.16697 | Val_loss: 0.23612 % | time: 0.184(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.14628 | Val_loss: 0.21790 % | time: 0.182(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.11861 | Val_loss: 0.20013 % | time: 0.178(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.08279 | Val_loss: 0.17161 % | time: 0.18(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.05472 | Val_loss: 0.14547 % | time: 0.178(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03507 | Val_loss: 0.12489 % | time: 0.177(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03121 | Val_loss: 0.10290 % | time: 0.174(s) | lr:  5e-06
# Epoch:   12  | Loss = 0.03547 | Val_loss: 0.08952 % | time: 0.173(s) | lr:  5e-06
# Epoch:   13  | Loss = 0.03951 | Val_loss: 0.07996 % | time: 0.172(s) | lr:  5e-06
# Epoch:   14  | Loss = 0.04015 | Val_loss: 0.07894 % | time: 0.174(s) | lr:  5e-06
# Epoch:   15  | Loss = 0.03510 | Val_loss: 0.07241 % | time: 0.18(s) | lr:  5e-06
# Epoch:   16  | Loss = 0.02959 | Val_loss: 0.07070 % | time: 0.175(s) | lr:  5e-06
# Epoch:   17  | Loss = 0.02374 | Val_loss: 0.07083 % | time: 0.169(s) | lr:  1.75e-06
# Epoch:   18  | Loss = 0.02162 | Val_loss: 0.07015 % | time: 0.172(s) | lr:  1.75e-06
# Epoch:   19  | Loss = 0.02028 | Val_loss: 0.07063 % | time: 0.172(s) | lr:  6.125e-07
# Epoch:   20  | Loss = 0.02082 | Val_loss: 0.07047 % | time: 0.171(s) | lr:  2.1437499999999996e-07
# Done. Training Time:  Fri Dec  3 03:23:56 2021
# Total consumed time: 4.938058614730835
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-23000.889915820408, 7960.566753149033]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  24.75
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:24:21 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.34170 | Val_loss: 0.24431 % | time: 0.363(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.11671 | Val_loss: 0.17886 % | time: 0.278(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.05351 | Val_loss: 0.13979 % | time: 0.291(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.04150 | Val_loss: 0.10846 % | time: 0.296(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.03813 | Val_loss: 0.09542 % | time: 0.294(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.03504 | Val_loss: 0.08503 % | time: 0.285(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.03356 | Val_loss: 0.07262 % | time: 0.286(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.03272 | Val_loss: 0.06895 % | time: 0.286(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.03010 | Val_loss: 0.06579 % | time: 0.274(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.02863 | Val_loss: 0.06785 % | time: 0.277(s) | lr:  1.75e-06
# Epoch:   11  | Loss = 0.02765 | Val_loss: 0.06646 % | time: 0.281(s) | lr:  6.125e-07
# Epoch:   12  | Loss = 0.02723 | Val_loss: 0.07263 % | time: 0.284(s) | lr:  2.1437499999999996e-07
# Epoch:   13  | Loss = 0.02735 | Val_loss: 0.06960 % | time: 0.284(s) | lr:  7.503124999999999e-08
# Done. Training Time:  Fri Dec  3 03:24:26 2021
# Total consumed time: 4.500170707702637
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [18066.847360330095, 7244.538700580597]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.29
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:24:41 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.69168 | Val_loss: 0.29309 % | time: 0.235(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.38515 | Val_loss: 0.29892 % | time: 0.213(s) | lr:  1.75e-06
# Epoch:    3  | Loss = 0.27584 | Val_loss: 0.30045 % | time: 0.199(s) | lr:  6.125e-07
# Epoch:    4  | Loss = 0.25390 | Val_loss: 0.29064 % | time: 0.193(s) | lr:  6.125e-07
# Epoch:    5  | Loss = 0.24544 | Val_loss: 0.27446 % | time: 0.194(s) | lr:  6.125e-07
# Epoch:    6  | Loss = 0.21820 | Val_loss: 0.25562 % | time: 0.182(s) | lr:  6.125e-07
# Epoch:    7  | Loss = 0.17625 | Val_loss: 0.22859 % | time: 0.179(s) | lr:  6.125e-07
# Epoch:    8  | Loss = 0.12940 | Val_loss: 0.19997 % | time: 0.174(s) | lr:  6.125e-07
# Epoch:    9  | Loss = 0.08786 | Val_loss: 0.16987 % | time: 0.176(s) | lr:  6.125e-07
# Epoch:   10  | Loss = 0.06178 | Val_loss: 0.13066 % | time: 0.173(s) | lr:  6.125e-07
# Epoch:   11  | Loss = 0.05817 | Val_loss: 0.10647 % | time: 0.177(s) | lr:  6.125e-07
# Epoch:   12  | Loss = 0.06248 | Val_loss: 0.09407 % | time: 0.174(s) | lr:  6.125e-07
# Epoch:   13  | Loss = 0.06942 | Val_loss: 0.08369 % | time: 0.172(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.06657 | Val_loss: 0.08511 % | time: 0.169(s) | lr:  2.1437499999999996e-07
# Epoch:   15  | Loss = 0.06177 | Val_loss: 0.07800 % | time: 0.173(s) | lr:  2.1437499999999996e-07
# Epoch:   16  | Loss = 0.06212 | Val_loss: 0.07489 % | time: 0.178(s) | lr:  2.1437499999999996e-07
# Epoch:   17  | Loss = 0.05934 | Val_loss: 0.07507 % | time: 0.184(s) | lr:  7.503124999999999e-08
# Epoch:   18  | Loss = 0.05593 | Val_loss: 0.07864 % | time: 0.173(s) | lr:  2.6260937499999994e-08
# Epoch:   19  | Loss = 0.05641 | Val_loss: 0.08055 % | time: 0.174(s) | lr:  9.191328124999997e-09
# Epoch:   20  | Loss = 0.05767 | Val_loss: 0.08098 % | time: 0.177(s) | lr:  3.2169648437499986e-09
# Done. Training Time:  Fri Dec  3 03:24:46 2021
# Total consumed time: 4.660245180130005
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-23219.902501523, 979.6113729476929]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  24.74
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:25:11 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.40733 | Val_loss: 0.26175 % | time: 0.283(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.15529 | Val_loss: 0.21649 % | time: 0.294(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.07626 | Val_loss: 0.17538 % | time: 0.29(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.05551 | Val_loss: 0.13607 % | time: 0.296(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.05064 | Val_loss: 0.10662 % | time: 0.293(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.04300 | Val_loss: 0.10078 % | time: 0.284(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.03766 | Val_loss: 0.08808 % | time: 0.287(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.03500 | Val_loss: 0.07730 % | time: 0.278(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.03384 | Val_loss: 0.07109 % | time: 0.275(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03297 | Val_loss: 0.07244 % | time: 0.275(s) | lr:  1.75e-06
# Epoch:   11  | Loss = 0.03096 | Val_loss: 0.06901 % | time: 0.278(s) | lr:  1.75e-06
# Epoch:   12  | Loss = 0.02981 | Val_loss: 0.06781 % | time: 0.276(s) | lr:  1.75e-06
# Epoch:   13  | Loss = 0.02957 | Val_loss: 0.06884 % | time: 0.277(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.02939 | Val_loss: 0.06803 % | time: 0.278(s) | lr:  2.1437499999999996e-07
# Epoch:   15  | Loss = 0.02916 | Val_loss: 0.07181 % | time: 0.28(s) | lr:  7.503124999999999e-08
# Epoch:   16  | Loss = 0.02918 | Val_loss: 0.06877 % | time: 0.281(s) | lr:  2.6260937499999994e-08
# Done. Training Time:  Fri Dec  3 03:25:16 2021
# Total consumed time: 5.363988637924194
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [18011.599877296096, -709.5571756362915]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.56
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:25:32 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.83017 | Val_loss: 0.29100 % | time: 0.24(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.49488 | Val_loss: 0.31696 % | time: 0.209(s) | lr:  1.75e-06
# Epoch:    3  | Loss = 0.36792 | Val_loss: 0.32146 % | time: 0.196(s) | lr:  6.125e-07
# Epoch:    4  | Loss = 0.34295 | Val_loss: 0.33955 % | time: 0.186(s) | lr:  2.1437499999999996e-07
# Epoch:    5  | Loss = 0.33503 | Val_loss: 0.33594 % | time: 0.186(s) | lr:  7.503124999999999e-08
# Done. Training Time:  Fri Dec  3 03:25:33 2021
# Total consumed time: 1.1014578342437744
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-22800.015488508867, 14719.612258858979]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  25.47
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:25:58 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.57298 | Val_loss: 0.26675 % | time: 0.301(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.26280 | Val_loss: 0.25975 % | time: 0.295(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.13601 | Val_loss: 0.23151 % | time: 0.281(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.10127 | Val_loss: 0.20632 % | time: 0.289(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.08590 | Val_loss: 0.17576 % | time: 0.29(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.06544 | Val_loss: 0.14604 % | time: 0.285(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.04935 | Val_loss: 0.12308 % | time: 0.284(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.04103 | Val_loss: 0.09021 % | time: 0.282(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.04343 | Val_loss: 0.08185 % | time: 0.28(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.04139 | Val_loss: 0.07062 % | time: 0.271(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03748 | Val_loss: 0.07213 % | time: 0.278(s) | lr:  1.75e-06
# Epoch:   12  | Loss = 0.03464 | Val_loss: 0.06702 % | time: 0.28(s) | lr:  1.75e-06
# Epoch:   13  | Loss = 0.03444 | Val_loss: 0.07070 % | time: 0.288(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.03467 | Val_loss: 0.06794 % | time: 0.277(s) | lr:  2.1437499999999996e-07
# Epoch:   15  | Loss = 0.03389 | Val_loss: 0.06824 % | time: 0.282(s) | lr:  7.503124999999999e-08
# Epoch:   16  | Loss = 0.03284 | Val_loss: 0.06580 % | time: 0.284(s) | lr:  7.503124999999999e-08
# Epoch:   17  | Loss = 0.03316 | Val_loss: 0.06648 % | time: 0.279(s) | lr:  2.6260937499999994e-08
# Epoch:   18  | Loss = 0.03282 | Val_loss: 0.06799 % | time: 0.279(s) | lr:  9.191328124999997e-09
# Epoch:   19  | Loss = 0.03322 | Val_loss: 0.06851 % | time: 0.283(s) | lr:  3.2169648437499986e-09
# Epoch:   20  | Loss = 0.03290 | Val_loss: 0.06883 % | time: 0.286(s) | lr:  1.1259376953124994e-09
# Done. Training Time:  Fri Dec  3 03:26:05 2021
# Total consumed time: 6.568872451782227
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [18098.203897368297, 302.29512453079224]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.47
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:26:21 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.43312 | Val_loss: 0.26231 % | time: 0.235(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.18722 | Val_loss: 0.22446 % | time: 0.215(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.09868 | Val_loss: 0.20006 % | time: 0.196(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.07693 | Val_loss: 0.17667 % | time: 0.198(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.06771 | Val_loss: 0.15116 % | time: 0.185(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.06103 | Val_loss: 0.13447 % | time: 0.177(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.05300 | Val_loss: 0.11455 % | time: 0.178(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.04472 | Val_loss: 0.10531 % | time: 0.188(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.03618 | Val_loss: 0.09577 % | time: 0.174(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03083 | Val_loss: 0.08335 % | time: 0.176(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.02892 | Val_loss: 0.08180 % | time: 0.173(s) | lr:  5e-06
# Epoch:   12  | Loss = 0.02906 | Val_loss: 0.07714 % | time: 0.173(s) | lr:  5e-06
# Epoch:   13  | Loss = 0.02827 | Val_loss: 0.07282 % | time: 0.171(s) | lr:  5e-06
# Epoch:   14  | Loss = 0.02758 | Val_loss: 0.06947 % | time: 0.172(s) | lr:  5e-06
# Epoch:   15  | Loss = 0.02454 | Val_loss: 0.06866 % | time: 0.171(s) | lr:  5e-06
# Epoch:   16  | Loss = 0.02179 | Val_loss: 0.06522 % | time: 0.175(s) | lr:  5e-06
# Epoch:   17  | Loss = 0.02161 | Val_loss: 0.06442 % | time: 0.171(s) | lr:  5e-06
# Epoch:   18  | Loss = 0.01930 | Val_loss: 0.07066 % | time: 0.173(s) | lr:  1.75e-06
# Epoch:   19  | Loss = 0.01892 | Val_loss: 0.07154 % | time: 0.174(s) | lr:  6.125e-07
# Epoch:   20  | Loss = 0.01847 | Val_loss: 0.07381 % | time: 0.175(s) | lr:  2.1437499999999996e-07
# Done. Training Time:  Fri Dec  3 03:26:25 2021
# Total consumed time: 4.922162294387817
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-22774.910652634382, 13984.282103180885]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  24.94
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:26:51 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.33492 | Val_loss: 0.24016 % | time: 0.284(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.11083 | Val_loss: 0.18753 % | time: 0.29(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.05653 | Val_loss: 0.14575 % | time: 0.29(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.04227 | Val_loss: 0.10901 % | time: 0.293(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.03892 | Val_loss: 0.09308 % | time: 0.292(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.03586 | Val_loss: 0.08291 % | time: 0.289(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.03244 | Val_loss: 0.07625 % | time: 0.282(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.03126 | Val_loss: 0.06663 % | time: 0.284(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.02907 | Val_loss: 0.06673 % | time: 0.275(s) | lr:  1.75e-06
# Epoch:   10  | Loss = 0.02828 | Val_loss: 0.06953 % | time: 0.285(s) | lr:  6.125e-07
# Epoch:   11  | Loss = 0.02886 | Val_loss: 0.06684 % | time: 0.286(s) | lr:  2.1437499999999996e-07
# Epoch:   12  | Loss = 0.02798 | Val_loss: 0.06779 % | time: 0.285(s) | lr:  7.503124999999999e-08
# Done. Training Time:  Fri Dec  3 03:26:55 2021
# Total consumed time: 4.101055383682251
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [17926.99140613367, 2095.551961660385]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.61
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:27:10 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.61728 | Val_loss: 0.30765 % | time: 0.235(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.37309 | Val_loss: 0.28903 % | time: 0.217(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.25632 | Val_loss: 0.26410 % | time: 0.197(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.21418 | Val_loss: 0.24839 % | time: 0.196(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.20032 | Val_loss: 0.23355 % | time: 0.186(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.17711 | Val_loss: 0.21504 % | time: 0.178(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.14069 | Val_loss: 0.18664 % | time: 0.18(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.09652 | Val_loss: 0.17038 % | time: 0.177(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.06306 | Val_loss: 0.14545 % | time: 0.182(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03993 | Val_loss: 0.12443 % | time: 0.176(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03482 | Val_loss: 0.11260 % | time: 0.171(s) | lr:  5e-06
# Epoch:   12  | Loss = 0.04010 | Val_loss: 0.09657 % | time: 0.172(s) | lr:  5e-06
# Epoch:   13  | Loss = 0.04554 | Val_loss: 0.09001 % | time: 0.175(s) | lr:  5e-06
# Epoch:   14  | Loss = 0.04625 | Val_loss: 0.08128 % | time: 0.171(s) | lr:  5e-06
# Epoch:   15  | Loss = 0.04037 | Val_loss: 0.07892 % | time: 0.174(s) | lr:  5e-06
# Epoch:   16  | Loss = 0.03124 | Val_loss: 0.07493 % | time: 0.18(s) | lr:  5e-06
# Epoch:   17  | Loss = 0.02635 | Val_loss: 0.07336 % | time: 0.172(s) | lr:  5e-06
# Epoch:   18  | Loss = 0.02459 | Val_loss: 0.07550 % | time: 0.169(s) | lr:  1.75e-06
# Epoch:   19  | Loss = 0.02411 | Val_loss: 0.07598 % | time: 0.177(s) | lr:  6.125e-07
# Epoch:   20  | Loss = 0.02352 | Val_loss: 0.07281 % | time: 0.177(s) | lr:  6.125e-07
# Done. Training Time:  Fri Dec  3 03:27:15 2021
# Total consumed time: 5.023115158081055
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-23316.538524493197, 845.4829335212708]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  25.13
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:27:41 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.39669 | Val_loss: 0.23452 % | time: 0.287(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.14454 | Val_loss: 0.20452 % | time: 0.292(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.07140 | Val_loss: 0.15699 % | time: 0.295(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.05491 | Val_loss: 0.13144 % | time: 0.298(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.04794 | Val_loss: 0.12034 % | time: 0.294(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.04127 | Val_loss: 0.09669 % | time: 0.283(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.03612 | Val_loss: 0.08375 % | time: 0.278(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.03363 | Val_loss: 0.07759 % | time: 0.286(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.03257 | Val_loss: 0.06651 % | time: 0.283(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03145 | Val_loss: 0.06783 % | time: 0.284(s) | lr:  1.75e-06
# Epoch:   11  | Loss = 0.02962 | Val_loss: 0.06494 % | time: 0.283(s) | lr:  1.75e-06
# Epoch:   12  | Loss = 0.02848 | Val_loss: 0.06585 % | time: 0.296(s) | lr:  6.125e-07
# Epoch:   13  | Loss = 0.02827 | Val_loss: 0.07060 % | time: 0.282(s) | lr:  2.1437499999999996e-07
# Epoch:   14  | Loss = 0.02783 | Val_loss: 0.07372 % | time: 0.281(s) | lr:  7.503124999999999e-08
# Epoch:   15  | Loss = 0.02807 | Val_loss: 0.06748 % | time: 0.282(s) | lr:  7.503124999999999e-08
# Done. Training Time:  Fri Dec  3 03:27:46 2021
# Total consumed time: 5.022770404815674
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [18041.618612173046, 1359.9000453948975]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.33
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:28:01 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.53123 | Val_loss: 0.30134 % | time: 0.236(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.28773 | Val_loss: 0.29001 % | time: 0.209(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.17880 | Val_loss: 0.28604 % | time: 0.195(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.14792 | Val_loss: 0.26039 % | time: 0.186(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.13160 | Val_loss: 0.23947 % | time: 0.179(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.11736 | Val_loss: 0.22668 % | time: 0.172(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.09557 | Val_loss: 0.20206 % | time: 0.173(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.07168 | Val_loss: 0.16814 % | time: 0.173(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.04961 | Val_loss: 0.14181 % | time: 0.176(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.03815 | Val_loss: 0.11763 % | time: 0.175(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03329 | Val_loss: 0.09538 % | time: 0.175(s) | lr:  5e-06
# Epoch:   12  | Loss = 0.03571 | Val_loss: 0.08337 % | time: 0.169(s) | lr:  5e-06
# Epoch:   13  | Loss = 0.03841 | Val_loss: 0.07840 % | time: 0.177(s) | lr:  5e-06
# Epoch:   14  | Loss = 0.03737 | Val_loss: 0.07373 % | time: 0.169(s) | lr:  5e-06
# Epoch:   15  | Loss = 0.03349 | Val_loss: 0.07186 % | time: 0.172(s) | lr:  5e-06
# Epoch:   16  | Loss = 0.02870 | Val_loss: 0.06886 % | time: 0.17(s) | lr:  5e-06
# Epoch:   17  | Loss = 0.02512 | Val_loss: 0.07617 % | time: 0.178(s) | lr:  1.75e-06
# Epoch:   18  | Loss = 0.02276 | Val_loss: 0.06697 % | time: 0.17(s) | lr:  1.75e-06
# Epoch:   19  | Loss = 0.02196 | Val_loss: 0.06910 % | time: 0.173(s) | lr:  6.125e-07
# Epoch:   20  | Loss = 0.02217 | Val_loss: 0.07088 % | time: 0.172(s) | lr:  2.1437499999999996e-07
# Done. Training Time:  Fri Dec  3 03:28:06 2021
# Total consumed time: 4.869946479797363
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-23224.20580680971, 6294.648969173431]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ================================================================================
# image_width:10, TIME_RANGE:5000, B_init:2000, B_end:15000
# ================================================================================
# ========================================================================
# A_first:17850, A_end:17950, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  24.63
# total_parameter:  7.60781 M
# ==================== A_idx: 17850, B_idx: 2000 ======================
# train_batch:  11264 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:28:31 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.69136 | Val_loss: 0.28319 % | time: 0.283(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.30179 | Val_loss: 0.27028 % | time: 0.284(s) | lr:  5e-06
# Epoch:    3  | Loss = 0.15802 | Val_loss: 0.23528 % | time: 0.298(s) | lr:  5e-06
# Epoch:    4  | Loss = 0.11346 | Val_loss: 0.20367 % | time: 0.29(s) | lr:  5e-06
# Epoch:    5  | Loss = 0.09884 | Val_loss: 0.17997 % | time: 0.294(s) | lr:  5e-06
# Epoch:    6  | Loss = 0.07226 | Val_loss: 0.15451 % | time: 0.283(s) | lr:  5e-06
# Epoch:    7  | Loss = 0.04978 | Val_loss: 0.12414 % | time: 0.285(s) | lr:  5e-06
# Epoch:    8  | Loss = 0.04182 | Val_loss: 0.09453 % | time: 0.281(s) | lr:  5e-06
# Epoch:    9  | Loss = 0.04342 | Val_loss: 0.08117 % | time: 0.274(s) | lr:  5e-06
# Epoch:   10  | Loss = 0.04251 | Val_loss: 0.07305 % | time: 0.271(s) | lr:  5e-06
# Epoch:   11  | Loss = 0.03789 | Val_loss: 0.07470 % | time: 0.285(s) | lr:  1.75e-06
# Epoch:   12  | Loss = 0.03406 | Val_loss: 0.06871 % | time: 0.283(s) | lr:  1.75e-06
# Epoch:   13  | Loss = 0.03370 | Val_loss: 0.07349 % | time: 0.287(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.03353 | Val_loss: 0.06900 % | time: 0.279(s) | lr:  2.1437499999999996e-07
# Epoch:   15  | Loss = 0.03222 | Val_loss: 0.06693 % | time: 0.281(s) | lr:  2.1437499999999996e-07
# Epoch:   16  | Loss = 0.03310 | Val_loss: 0.07212 % | time: 0.288(s) | lr:  7.503124999999999e-08
# Epoch:   17  | Loss = 0.03273 | Val_loss: 0.06901 % | time: 0.281(s) | lr:  2.6260937499999994e-08
# Epoch:   18  | Loss = 0.03293 | Val_loss: 0.07238 % | time: 0.28(s) | lr:  9.191328124999997e-09
# Epoch:   19  | Loss = 0.03283 | Val_loss: 0.06910 % | time: 0.281(s) | lr:  3.2169648437499986e-09
# Done. Training Time:  Fri Dec  3 03:28:37 2021
# Total consumed time: 6.272621393203735
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [18000.  2800.]
# Prediction Value:  [17722.963839627064, 15668.806304037571]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.
# ========================================================================
# A_first:-23050, A_end:-23000, B_first:2000, B_end:15000, Bat_mul:64
# ========================================================================
# class_idx: 0 Time consumed(s):  15.22
# total_parameter:  7.564802 M
# ==================== A_idx: -23050, B_idx: 2000 ======================
# train_batch:  6144 valid_batch:  4096
#
#
# ========================================================================================================
#  Training Start:  Fri Dec  3 03:28:52 2021
#  mini_batch: 2048  | learning_rate:  5e-06  | selected_optim_name:  ['Adabound', [30, 15, 7, 1]]  |
# ========================================================================================================
# Epoch:    1  | Loss = 0.55715 | Val_loss: 0.31911 % | time: 0.235(s) | lr:  5e-06
# Epoch:    2  | Loss = 0.30016 | Val_loss: 0.32944 % | time: 0.216(s) | lr:  1.75e-06
# Epoch:    3  | Loss = 0.19855 | Val_loss: 0.32849 % | time: 0.197(s) | lr:  6.125e-07
# Epoch:    4  | Loss = 0.17736 | Val_loss: 0.32167 % | time: 0.189(s) | lr:  6.125e-07
# Epoch:    5  | Loss = 0.16778 | Val_loss: 0.30552 % | time: 0.186(s) | lr:  6.125e-07
# Epoch:    6  | Loss = 0.15459 | Val_loss: 0.28206 % | time: 0.188(s) | lr:  6.125e-07
# Epoch:    7  | Loss = 0.12690 | Val_loss: 0.24859 % | time: 0.187(s) | lr:  6.125e-07
# Epoch:    8  | Loss = 0.09681 | Val_loss: 0.21552 % | time: 0.181(s) | lr:  6.125e-07
# Epoch:    9  | Loss = 0.07013 | Val_loss: 0.17484 % | time: 0.17(s) | lr:  6.125e-07
# Epoch:   10  | Loss = 0.05641 | Val_loss: 0.13792 % | time: 0.174(s) | lr:  6.125e-07
# Epoch:   11  | Loss = 0.05139 | Val_loss: 0.10469 % | time: 0.174(s) | lr:  6.125e-07
# Epoch:   12  | Loss = 0.05391 | Val_loss: 0.08831 % | time: 0.173(s) | lr:  6.125e-07
# Epoch:   13  | Loss = 0.05759 | Val_loss: 0.07612 % | time: 0.171(s) | lr:  6.125e-07
# Epoch:   14  | Loss = 0.05746 | Val_loss: 0.07832 % | time: 0.169(s) | lr:  2.1437499999999996e-07
# Epoch:   15  | Loss = 0.05334 | Val_loss: 0.07027 % | time: 0.173(s) | lr:  2.1437499999999996e-07
# Epoch:   16  | Loss = 0.05316 | Val_loss: 0.07562 % | time: 0.176(s) | lr:  7.503124999999999e-08
# Epoch:   17  | Loss = 0.05260 | Val_loss: 0.06943 % | time: 0.174(s) | lr:  7.503124999999999e-08
# Epoch:   18  | Loss = 0.05244 | Val_loss: 0.07046 % | time: 0.175(s) | lr:  2.6260937499999994e-08
# Epoch:   19  | Loss = 0.05018 | Val_loss: 0.07640 % | time: 0.172(s) | lr:  9.191328124999997e-09
# Epoch:   20  | Loss = 0.05145 | Val_loss: 0.07301 % | time: 0.174(s) | lr:  3.2169648437499986e-09
# Done. Training Time:  Fri Dec  3 03:28:57 2021
# Total consumed time: 4.603405475616455
# Model loaded as evalutation mode. Model path: /test_regression/reg_model_N256_batch2048_lr5e-06_Adabound.pt
# Target Value:  [-23000.   8700.]
# Prediction Value:  [-23543.340888989318, 9281.848984956741]
#
#  This predicted value is used as the initial guess value for the fine-tuning step.

# %%
total_pred_list = np.array(total_pred_list)
first_spin = (total_pred_list[0] + total_pred_list[2] + total_pred_list[4]) / 3
second_spin = (total_pred_list[1] + total_pred_list[3] + total_pred_list[5]) / 3

print("Averaged Prediction Value of 1st target spin: ",
      "A: {0} (target A: {1})".format(round(first_spin[0],2), round(test_spins[0,0]/2/np.pi,2)),
      "B: {0} (target B: {1})".format(round(first_spin[1],2), round(test_spins[0,1]/2/np.pi,2)))
print("Averaged Prediction Value of 2nd target spin: ",
      "A: {0} (target A: {1})".format(round(second_spin[0],2), round(test_spins[1,0]/2/np.pi,2)),
      "B: {0} (target B: {1})".format(round(second_spin[1],2), round(test_spins[1,1]/2/np.pi,2)))
# Out:
# Averaged Prediction Value of 1st target spin:  A: 18000.99 (target A: 18000.0) B: 3756.08 (target B: 2800.0)
# Averaged Prediction Value of 2nd target spin:  A: -23006.94 (target A: -23000.0) B: 7886.6 (target B: 8700.0)

# %% [markdown]
# ### The results are used as inital guess values for Particle Swarm Optimization (PSO) tuning method.
